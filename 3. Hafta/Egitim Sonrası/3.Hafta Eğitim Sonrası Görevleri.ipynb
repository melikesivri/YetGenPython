# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
sayi =int(input("Bir sayı girin:"))

if sayi > 0:
    print("pozitif")
elif sayi < 0:
    print("negatif")
else:
    print("Sıfır")
# Out:
# pozitif

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
sayi = int(input("Bir sayı girin:"))
toplam = 0
for i in range(1, sayi):

    if sayi%1 == 0:
        toplam +=i
        print(toplam)

if toplam == sayi:
    print("mükemmel sayı")
else:
    print("mükemmel sayı değil")
# Out:
# 1
# 3
# mükemmel sayı

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
sayi = int(input("sayi giriniz:"))
basamak = str(sayi)

toplam = 0

for x in basamak:
    rakam = int(x) ** len(basamak)  #len fonksiyonu basamak uzunluğunu verir
    toplam += rakam

if sayi == toplam:
    print("armstrong") 
else:
    print("değil")
# Out:
# armstrong

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
for i in range(1,11):

    for j in range(0,11):
        print(f"{i} x {j} = {i*j}")
# Out:
# 1 x 0 = 0
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 0 = 0
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 0 = 0
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 0 = 0
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 0 = 0
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 0 = 0
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 0 = 0
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 9 x 0 = 0
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# 10 x 0 = 0
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
toplam = 0
while True:
    karar = input("çıkış için 'q' diğer seçenekler için sayı girin:")

if karar =="q":
    print("Çıkış yapıldı")
    break
else:
   sayi = int(karar)

   toplam += sayi

print(toplam)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 toplam = 0
#       2 while True:
# ----> 3     karar = input("çıkış için 'q' diğer seçenekler için sayı girin:")
#       5 if karar =='q':
#       6     print("Çıkış yapıldı")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1187, in Kernel.raw_input(self, prompt)
#    1185     msg = "raw_input was called, but this frontend does not support input requests."
#    1186     raise StdinNotImplementedError(msg)
# -> 1187 return self._input_request(
#    1188     str(prompt),
#    1189     self._parent_ident["shell"],
#    1190     self.get_parent("shell"),
#    1191     password=False,
#    1192 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1230, in Kernel._input_request(self, prompt, ident, parent, password)
#    1227 except KeyboardInterrupt:
#    1228     # re-raise KeyboardInterrupt, to truncate traceback
#    1229     msg = "Interrupted by user"
# -> 1230     raise KeyboardInterrupt(msg) from None
#    1231 except Exception:
#    1232     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
for i in range(1,101):
    if i % 3 ==0:
        print(i)
    else:
        continue
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
for i in range(1, 101):
    if i%15 == 0:
        print("yetgen")

    elif i%3 ==0:
        print("yet")
    elif i%5 ==0:
        print("gen")
    else:
        print(i)
# Out:
# 1
# 2
# yet
# 4
# gen
# yet
# 7
# 8
# yet
# gen
# 11
# yet
# 13
# 14
# yetgen
# 16
# 17
# yet
# 19
# gen
# yet
# 22
# 23
# yet
# gen
# 26
# yet
# 28
# 29
# yetgen
# 31
# 32
# yet
# 34
# gen
# yet
# 37
# 38
# yet
# gen
# 41
# yet
# 43
# 44
# yetgen
# 46
# 47
# yet
# 49
# gen
# yet
# 52
# 53
# yet
# gen
# 56
# yet
# 58
# 59
# yetgen
# 61
# 62
# yet
# 64
# gen
# yet
# 67
# 68
# yet
# gen
# 71
# yet
# 73
# 74
# yetgen
# 76
# 77
# yet
# 79
# gen
# yet
# 82
# 83
# yet
# gen
# 86
# yet
# 88
# 89
# yetgen
# 91
# 92
# yet
# 94
# gen
# yet
# 97
# 98
# yet
# gen
