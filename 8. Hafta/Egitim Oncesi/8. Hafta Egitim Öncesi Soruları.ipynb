# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urun_kayit():
    
    urunAdi = input("Ürün adı giriniz: ")
    urunFiyati = input("Ürün fiyatı giriniz: ")

    with open("urunler.txt", "a") as f:
        f.write(f"{urunAdi}, {urunFiyati}\n")

urun_kayit()

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def kelimeDegistir(eskiKelime, yeniKelime):
   
    with open("urunler.txt", "r") as f:
        dosya_icerigi = f.read()

   
    yeni_dosya_icerigi = dosya_icerigi.replace(eskiKelime, yeniKelime)

   
    with open("urunler.txt", "w") as f:
        f.write(yeni_dosya_icerigi)

    print(f"{eskiKelime} kelimesi {yeniKelime} kelimesi ile değiştirildi.")

kelimeDegistir(eskiKelime= buyuk, yeniKelime= kucuk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      11         f.write(yeni_dosya_icerigi)
#      13     print(f"{eskiKelime} kelimesi {yeniKelime} kelimesi ile değiştirildi.")
# ---> 15 kelimeDegistir(eskiKelime= buyuk, yeniKelime= kucuk)
#
# NameError: name 'buyuk' is not defined

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```
